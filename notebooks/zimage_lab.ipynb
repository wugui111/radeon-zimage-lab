# %% [markdown]
# # Radeon Cloud Z-Image-Turbo 生图实验
#
# 本 Notebook 用于在 Radeon Cloud 上检查 GPU、安装依赖、部署 Z-Image-Turbo，并生成一张图片。

# %% [markdown]
# ## 1. 检查 GPU

# %%
# !python scripts/00_check_gpu.py

# %% [markdown]
# ## 2. 安装依赖

# %%
# !bash scripts/install_deps.sh

# %% [markdown]
# ## 3. 生成图片

# %%
# !python scripts/00_check_gpu.py
# !python scripts/01_generate_zimage.py --prompt "为软件技术专业实训周设计一张中文宣传海报，主题是云计算与人工智能应用开发，蓝白科技风，清晰中文标题，现代设计，高质量" --height 768 --width 768 --output outputs/zimage_result.png

# %% [markdown]
# ## 4. 查看结果
#
# 生成图片保存在 `outputs/zimage_result.png`。

# %%
from IPython.display import Image, display
display(Image(filename="outputs/zimage_result.png"))

# %% [markdown]
# ## 5. 启动网页应用（可选）
#
# 如果平台支持端口代理，可以在终端运行：
#
# ```bash
# python scripts/02_gradio_zimage_app.py
# ```
